# %% [markdown]
# <a href="https://colab.research.google.com/github/KryssyCo/DS-Unit-1-Sprint-5-Data-Storytelling-Blog-Post/blob/master/Finished_Child_Protection_2017_Data_National.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://raw.githubusercontent.com/KryssyCo/DS-Unit-1-Sprint-5-Data-Storytelling-Blog-Post/master/SISO%20National.csv')
print(df.shape)
df.tail().T
# Out:
# (1, 8)
#                           0
# State              National
# Screened_In         2359911
# Screened_out        1421252
# Total Referrals     3781163
# Substantiated        696785
# Unsubstantiated     2379710
# Closed_No_Finding     56337
# Voluntary            449926

# %%
# pd.display.options.width
# pd.display.options.max_rows

# %%
df.plot.bar()

# %%
plt.style.use('fivethirtyeight');
# fig = plt.figure(figsize=(18, 15));
#df.plot.bar(figsize=(5,4));
ax = df.plot(colormap = 'cividis', kind='bar', title = '2017 Child Abuse Screen and Disposition',width = 1.025, figsize=(9,15));
plt.xticks(rotation='horizontal')
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.xlabel('2017')
plt.ylabel('Amount of Children')
plt.title('2017 Child Abuse Screen and Disposition')
plt.show()
